# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('C:\\Users\\z5130037\\OneDrive - UNSW\CAVSeverityResults\\D0_results\\InputData\\10%\\FHZ_Files\\S000002_001.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
#df = pd.read_csv('C:\\Users\\z5130037\\OneDrive - UNSW\CAVSeverityResults\\D0_results\\InputData\\0%\\FHZ_Files\\S000001_001.csv', delimiter = ';', dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float })
#df.set_index(1)
#df["VehNo"]
#df

# %%
f = df.loc[df['VehType'] == 100]
f1 = f['VehNo']
f1save = f1.to_csv((r"C:\\Users\\z5130037\\OneDrive - UNSW\CAVSeverityResults\\D0_results\\InputData\\10%\\FHZ_Files\\bugsbunny1\\Manual1.csv"))
g = df.loc[df['VehType'] == 101]
g1 = g['VehNo']
g1save = g1.to_csv((r"C:\\Users\\z5130037\\OneDrive - UNSW\CAVSeverityResults\\D0_results\\InputData\\10%\\FHZ_Files\\bugsbunny1\\CAV1.csv"))

print(len(g1))
print(len(f1))
print(len(g1)+len(f1))
print(len(df))
# Out:
# 826
# 7514
# 8340
# 8340
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.

# %%
#reading the SSAM file 
data = pd.read_csv('C:\\Users\\z5130037\\OneDrive - UNSW\CAVSeverityResults\\D0_results\\InputData\\10%\\TRJ_Files\\S000002_001conflict.csv', delimiter = ',', header = 0)
length = len(data)
print(length)
#data.FirstVID[40]
#data
# Out:
# 3804

# %%
#Append new coloumn
data["Interaction_Type"] = ""
#data

# %%
for i in range (0, length):
    if ()
# Out:
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# nothing
# ...

# %%
for i in range (0, length):
    if(data.FirstVID[i] in (f1)) and (data.SecondVID[i] in (f1)):
        data.Interaction_Type[i] = 0
        
    elif(data.FirstVID[i] in (f1)) and (data.SecondVID[i] in (g1)):
        data.Interaction_Type[i] = 1
        
    elif(data.FirstVID[i] in (g1)) and (data.SecondVID[i] in (f1)):
        data.Interaction_Type[i] = 2
        
    elif(data.FirstVID[i] in (g1)) and (data.SecondVID[i] in (g1)):
        data.Interaction_Type[i] = 3
        
    else:
        print("flag this")
# Out:
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
datasave = data.to_csv((r"C:\\Users\\z5130037\\OneDrive - UNSW\CAVSeverityResults\\D0_results\\InputData\\10%\\FHZ_Files\\bugsbunny1\\Final1.csv"))
