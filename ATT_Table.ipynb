# %%
import pandas as pd

# %%
x = F = pd.read_csv("E:\ATTa2b2.csv", delimiter=';')
x
# Out:
#   $VEHICLENETWORKPERFORMANCEMEASUREMENTEVALUATION:SIMRUN TIMEINT  \
# 0                                                  1      0-3600
# 1                                                  2      0-3600
# 2                                                  3      0-3600
# 3                                                AVG      0-3600
# 4                                             STDDEV      0-3600
# 5                                                MIN      0-3600
# 6                                                MAX      0-3600
#
#    DELAYAVG(ALL)  STOPSAVG(ALL)  SPEEDAVG(ALL)  DELAYSTOPAVG(ALL)  \
# 0          46.26          48.83          50.95              24.25
# 1          48.42          50.30          50.62              25.60
# 2          48.18          51.94          50.63              24.95
# 3          47.62          50.36          50.73              24.93
# 4           1.18           1.55           0.19               0.68
# ...
