# %%
import pandas as pd 
import numpy as np

# %%
#SEED1 11 Cases

# %%
#[First block]
df0_1 = pd.read_csv('E:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000001_001.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df10_1 = pd.read_csv('E:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000002_001.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df20_1 = pd.read_csv('E:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000003_001.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df30_1 = pd.read_csv('E:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000004_001.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df40_1 = pd.read_csv('E:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000005_001.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df50_1 = pd.read_csv('E:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000006_001.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df60_1 = pd.read_csv('E:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000007_001.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df70_1 = pd.read_csv('E:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000008_001.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df80_1 = pd.read_csv('E:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000009_001.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df90_1 = pd.read_csv('E:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000010_001.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df100_1 = pd.read_csv('E:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000011_001.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)

# %%
#[SECOND BLOCLK]
f0_1 = df0_1.loc[df0_1['VehType'] == 100]
f1_0_1 = f0_1['VehNo']
g0_1 = df0_1.loc[df0_1['VehType'] == 101]
g1_0_1 = g0_1['VehNo']

f10_1 = df10_1.loc[df10_1['VehType'] == 100]
f1_10_1 = f10_1['VehNo']
g10_1 = df10_1.loc[df10_1['VehType'] == 101]
g1_10_1 = g10_1['VehNo']

f20_1 = df20_1.loc[df20_1['VehType'] == 100]
f1_20_1 = f20_1['VehNo']
g20_1 = df20_1.loc[df20_1['VehType'] == 101]
g1_20_1 = g20_1['VehNo']

f30_1 = df30_1.loc[df30_1['VehType'] == 100]
f1_30_1 = f30_1['VehNo']
g30_1 = df30_1.loc[df30_1['VehType'] == 101]
g1_30_1 = g30_1['VehNo']

f40_1 = df40_1.loc[df40_1['VehType'] == 100]
f1_40_1 = f40_1['VehNo']
g40_1 = df40_1.loc[df40_1['VehType'] == 101]
g1_40_1 = g40_1['VehNo']

f50_1 = df50_1.loc[df50_1['VehType'] == 100]
f1_50_1 = f50_1['VehNo']
g50_1 = df50_1.loc[df50_1['VehType'] == 101]
g1_50_1 = g50_1['VehNo']

f60_1 = df60_1.loc[df60_1['VehType'] == 100]
f1_60_1 = f60_1['VehNo']
g60_1 = df60_1.loc[df60_1['VehType'] == 101]
g1_60_1 = g60_1['VehNo']

f70_1 = df70_1.loc[df70_1['VehType'] == 100]
f1_70_1 = f70_1['VehNo']
g70_1 = df70_1.loc[df70_1['VehType'] == 101]
g1_70_1 = g70_1['VehNo']

f80_1 = df80_1.loc[df80_1['VehType'] == 100]
f1_80_1 = f80_1['VehNo']
g80_1 = df80_1.loc[df80_1['VehType'] == 101]
g1_80_1 = g80_1['VehNo']

f90_1 = df90_1.loc[df90_1['VehType'] == 100]
f1_90_1 = f90_1['VehNo']
g90_1 = df90_1.loc[df90_1['VehType'] == 101]
g1_90_1 = g90_1['VehNo']

f100_1 = df100_1.loc[df100_1['VehType'] == 100]
f1_100_1 = f100_1['VehNo']
g100_1 = df100_1.loc[df100_1['VehType'] == 101]
g1_100_1 = g100_1['VehNo']


f1save = f1_0_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual1.csv"))
g1save = g1_0_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV1.csv"))

f1save = f1_10_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual1.csv"))
g1save = g1_10_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV1.csv"))

f1save = f1_20_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual1.csv"))
g1save = g1_20_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV1.csv"))

f1save = f1_30_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual1.csv"))
g1save = g1_30_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV1.csv"))

f1save = f1_40_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual1.csv"))
g1save = g1_40_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV1.csv"))

f1save = f1_50_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual1.csv"))
g1save = g1_50_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV1.csv"))

f1save = f1_60_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual1.csv"))
g1save = g1_60_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV1.csv"))

f1save = f1_70_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual1.csv"))
g1save = g1_70_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV1.csv"))

f1save = f1_80_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual1.csv"))
g1save = g1_80_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV1.csv"))

f1save = f1_90_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual1.csv"))
g1save = g1_90_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV1.csv"))

f1save =f1_100_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual1.csv"))
g1save =g1_100_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV1.csv"))



print("0%")
print(len(f1_0_1))
print(len(g1_0_1))
print(len(g1_0_1)+len(f1_0_1))
print(len(df0_1))
      
print("Next Scenario --> MV --> AV --> total")
print("10%")
print(len(f1_10_1))
print(len(g1_10_1))
print(len(g1_10_1)+len(f1_10_1))
print(len(df10_1))
print("Next Scenario --> MV --> AV --> total")
print("20%")
print(len(f1_20_1))
print(len(g1_20_1))
print(len(g1_20_1)+len(f1_20_1))
print(len(df20_1))
print("Next Scenario --> MV --> AV --> total")
print("30%")
print(len(f1_30_1))
print(len(g1_30_1))
print(len(g1_30_1)+len(f1_30_1))
print(len(df30_1))
print("Next Scenario --> MV --> AV --> total")
print("40%")
print(len(f1_40_1))
print(len(g1_40_1))
print(len(g1_40_1)+len(f1_40_1))
print(len(df40_1))
print("Next Scenario --> MV --> AV --> total")
print("50%")
print(len(f1_50_1))
print(len(g1_50_1))
print(len(g1_50_1)+len(f1_50_1))
print(len(df50_1))
print("Next Scenario --> MV --> AV --> total")
print("60%")
print(len(f1_60_1))
print(len(g1_60_1))
print(len(g1_60_1)+len(f1_60_1))
print(len(df60_1))
print("Next Scenario --> MV --> AV --> total")
print("70%")
print(len(f1_70_1))
print(len(g1_70_1))
print(len(g1_70_1)+len(f1_70_1))
print(len(df70_1))
print("Next Scenario --> MV --> AV --> total")
print("80%")
print(len(f1_80_1))
print(len(g1_80_1))
print(len(g1_80_1)+len(f1_80_1))
print(len(df80_1))
print("Next Scenario --> MV --> AV --> total")
print("90%")
print(len(f1_90_1))
print(len(g1_90_1))
print(len(g1_90_1)+len(f1_90_1))
print(len(df90_1))
print("Next Scenario --> MV --> AV --> total")
print("100%")
print(len(f1_100_1))
print(len(g1_100_1))
print(len(g1_100_1)+len(f1_100_1))
print(len(df100_1))
print("Next Scenario --> MV --> AV --> total")
# Out:
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:58: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-5-689e5a720328> in <module>
#      56
#      57
# ---> 58 f1save = f1_0_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual1.csv"))
#      59 g1save = g1_0_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV1.csv"))
#      60
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\series.py in to_csv(self, *args, **kwargs)
#    4201                           stacklevel=2)
# ...

# %%
#[THIRD BLOCK]
#reading the SSAM file 
data0_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000001_001TRJ.csv', delimiter = ',', header = 0)
length0_1 = len(data0_1)
print(length0_1)

data10_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000002_001TRJ.csv', delimiter = ',', header = 0)
length10_1 = len(data10_1)
print(length10_1)

data20_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000003_001TRJ.csv', delimiter = ',', header = 0)
length20_1 = len(data20_1)
print(length20_1)

data30_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000004_001TRJ.csv', delimiter = ',', header = 0)
length30_1 = len(data30_1)
print(length30_1)

data40_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000005_001TRJ.csv', delimiter = ',', header = 0)
length40_1 = len(data40_1)
print(length40_1)

data50_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000006_001TRJ.csv', delimiter = ',', header = 0)
length50_1 = len(data50_1)
print(length50_1)

data60_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000007_001TRJ.csv', delimiter = ',', header = 0)
length60_1 = len(data60_1)
print(length60_1)

data70_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000008_001TRJ.csv', delimiter = ',', header = 0)
length70_1 = len(data70_1)
print(length70_1)

data80_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000009_001TRJ.csv', delimiter = ',', header = 0)
length80_1 = len(data80_1)
print(length80_1)

data90_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000010_001TRJ.csv', delimiter = ',', header = 0)
length90_1 = len(data90_1)
print(length90_1)

data100_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000011_001TRJ.csv', delimiter = ',', header = 0)
length100_1 = len(data100_1)
print(length100_1)


#Append new coloumn
data0_1["Interaction_Type"] = ""
data10_1["Interaction_Type"] = ""
data20_1["Interaction_Type"] = ""
data30_1["Interaction_Type"] = ""
data40_1["Interaction_Type"] = ""
data50_1["Interaction_Type"] = ""
data60_1["Interaction_Type"] = ""
data70_1["Interaction_Type"] = ""
data80_1["Interaction_Type"] = ""
data90_1["Interaction_Type"] = ""
data100_1["Interaction_Type"] = ""
# Out:
# 7333
# 3804
# 3129
# 2466
# 2496
# 2715
# 2884
# 2937
# 3145
# 3371
# 3594

# %%
#[FOURTH BLOCK]
for i in range (0, length0_1):
    if(data0_1.FirstVID[i] in (f1_0_1)) and (data0_1.SecondVID[i] in (f1_0_1)):
        data0_1.Interaction_Type[i] = 0
        
    elif(data0_1.FirstVID[i] in (f1_0_1)) and (data0_1.SecondVID[i] in (g1_0_1)):
        data0_1.Interaction_Type[i] = 1
        
    elif(data0_1.FirstVID[i] in (g1_0_1)) and (data0_1.SecondVID[i] in (f1_0_1)):
        data0_1.Interaction_Type[i] = 2
        
    elif(data0_1.FirstVID[i] in (g1_0_1)) and (data0_1.SecondVID[i] in (g1_0_1)):
        data0_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("0% done")   


for i in range (0, length10_1):
    if(data10_1.FirstVID[i] in (f1_10_1)) and (data10_1.SecondVID[i] in (f1_10_1)):
        data10_1.Interaction_Type[i] = 0
        
    elif(data10_1.FirstVID[i] in (f1_10_1)) and (data10_1.SecondVID[i] in (g1_10_1)):
        data10_1.Interaction_Type[i] = 1
        
    elif(data10_1.FirstVID[i] in (g1_10_1)) and (data10_1.SecondVID[i] in (f1_10_1)):
        data10_1.Interaction_Type[i] = 2
        
    elif(data10_1.FirstVID[i] in (g1_10_1)) and (data10_1.SecondVID[i] in (g1_10_1)):
        data10_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("10% done") 


for i in range (0, length20_1):
    if(data20_1.FirstVID[i] in (f1_20_1)) and (data20_1.SecondVID[i] in (f1_20_1)):
        data20_1.Interaction_Type[i] = 0
        
    elif(data20_1.FirstVID[i] in (f1_20_1)) and (data20_1.SecondVID[i] in (g1_20_1)):
        data20_1.Interaction_Type[i] = 1
        
    elif(data20_1.FirstVID[i] in (g1_20_1)) and (data20_1.SecondVID[i] in (f1_20_1)):
        data20_1.Interaction_Type[i] = 2
        
    elif(data20_1.FirstVID[i] in (g1_20_1)) and (data20_1.SecondVID[i] in (g1_20_1)):
        data20_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("20% done") 



for i in range (0, length30_1):
    if(data30_1.FirstVID[i] in (f1_30_1)) and (data30_1.SecondVID[i] in (f1_30_1)):
        data30_1.Interaction_Type[i] = 0
        
    elif(data30_1.FirstVID[i] in (f1_30_1)) and (data30_1.SecondVID[i] in (g1_30_1)):
        data30_1.Interaction_Type[i] = 1
        
    elif(data30_1.FirstVID[i] in (g1_30_1)) and (data30_1.SecondVID[i] in (f1_30_1)):
        data30_1.Interaction_Type[i] = 2
        
    elif(data30_1.FirstVID[i] in (g1_30_1)) and (data30_1.SecondVID[i] in (g1_30_1)):
        data30_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("30% done") 



for i in range (0, length40_1):
    if(data40_1.FirstVID[i] in (f1_40_1)) and (data40_1.SecondVID[i] in (f1_40_1)):
        data40_1.Interaction_Type[i] = 0
        
    elif(data40_1.FirstVID[i] in (f1_40_1)) and (data40_1.SecondVID[i] in (g1_40_1)):
        data40_1.Interaction_Type[i] = 1
        
    elif(data40_1.FirstVID[i] in (g1_40_1)) and (data40_1.SecondVID[i] in (f1_40_1)):
        data40_1.Interaction_Type[i] = 2
        
    elif(data40_1.FirstVID[i] in (g1_40_1)) and (data40_1.SecondVID[i] in (g1_40_1)):
        data40_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("40% done") 



for i in range (0, length50_1):
    if(data50_1.FirstVID[i] in (f1_50_1)) and (data50_1.SecondVID[i] in (f1_50_1)):
        data50_1.Interaction_Type[i] = 0
        
    elif(data50_1.FirstVID[i] in (f1_50_1)) and (data50_1.SecondVID[i] in (g1_50_1)):
        data50_1.Interaction_Type[i] = 1
        
    elif(data50_1.FirstVID[i] in (g1_50_1)) and (data50_1.SecondVID[i] in (f1_50_1)):
        data50_1.Interaction_Type[i] = 2
        
    elif(data50_1.FirstVID[i] in (g1_50_1)) and (data50_1.SecondVID[i] in (g1_50_1)):
        data50_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("50% done") 




for i in range (0, length60_1):
    if(data60_1.FirstVID[i] in (f1_60_1)) and (data60_1.SecondVID[i] in (f1_60_1)):
        data60_1.Interaction_Type[i] = 0
        
    elif(data60_1.FirstVID[i] in (f1_60_1)) and (data60_1.SecondVID[i] in (g1_60_1)):
        data60_1.Interaction_Type[i] = 1
        
    elif(data60_1.FirstVID[i] in (g1_60_1)) and (data60_1.SecondVID[i] in (f1_60_1)):
        data60_1.Interaction_Type[i] = 2
        
    elif(data60_1.FirstVID[i] in (g1_60_1)) and (data60_1.SecondVID[i] in (g1_60_1)):
        data60_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("60% done") 



for i in range (0, length70_1):
    if(data70_1.FirstVID[i] in (f1_70_1)) and (data70_1.SecondVID[i] in (f1_70_1)):
        data70_1.Interaction_Type[i] = 0
        
    elif(data70_1.FirstVID[i] in (f1_70_1)) and (data70_1.SecondVID[i] in (g1_70_1)):
        data70_1.Interaction_Type[i] = 1
        
    elif(data70_1.FirstVID[i] in (g1_70_1)) and (data70_1.SecondVID[i] in (f1_70_1)):
        data70_1.Interaction_Type[i] = 2
        
    elif(data70_1.FirstVID[i] in (g1_70_1)) and (data70_1.SecondVID[i] in (g1_70_1)):
        data70_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("70% done") 



for i in range (0, length80_1):
    if(data80_1.FirstVID[i] in (f1_80_1)) and (data80_1.SecondVID[i] in (f1_80_1)):
        data80_1.Interaction_Type[i] = 0
        
    elif(data80_1.FirstVID[i] in (f1_80_1)) and (data80_1.SecondVID[i] in (g1_80_1)):
        data80_1.Interaction_Type[i] = 1
        
    elif(data80_1.FirstVID[i] in (g1_80_1)) and (data80_1.SecondVID[i] in (f1_80_1)):
        data80_1.Interaction_Type[i] = 2
        
    elif(data80_1.FirstVID[i] in (g1_80_1)) and (data80_1.SecondVID[i] in (g1_80_1)):
        data80_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("80% done") 




for i in range (0, length90_1):
    if(data90_1.FirstVID[i] in (f1_90_1)) and (data90_1.SecondVID[i] in (f1_90_1)):
        data90_1.Interaction_Type[i] = 0
        
    elif(data90_1.FirstVID[i] in (f1_90_1)) and (data90_1.SecondVID[i] in (g1_90_1)):
        data90_1.Interaction_Type[i] = 1
        
    elif(data90_1.FirstVID[i] in (g1_90_1)) and (data90_1.SecondVID[i] in (f1_90_1)):
        data90_1.Interaction_Type[i] = 2
        
    elif(data90_1.FirstVID[i] in (g1_90_1)) and (data90_1.SecondVID[i] in (g1_90_1)):
        data90_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("90% done") 




for i in range (0, length100_1):
    if(data100_1.FirstVID[i] in (f1_100_1)) and (data100_1.SecondVID[i] in (f1_100_1)):
        data100_1.Interaction_Type[i] = 0
        
    elif(data100_1.FirstVID[i] in (f1_100_1)) and (data100_1.SecondVID[i] in (g1_100_1)):
        data100_1.Interaction_Type[i] = 1
        
    elif(data100_1.FirstVID[i] in (g1_100_1)) and (data100_1.SecondVID[i] in (f1_100_1)):
        data100_1.Interaction_Type[i] = 2
        
    elif(data100_1.FirstVID[i] in (g1_100_1)) and (data100_1.SecondVID[i] in (g1_100_1)):
        data100_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("100% done")
# Out:
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 0% done
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#[FIFTH BLOCK]
datasave0_1 = data0_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final0_1.csv"))
datasave10_1 = data10_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final10_1.csv"))
datasave20_1 = data20_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final20_1.csv"))
datasave30_1 = data30_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final30_1.csv"))
datasave40_1 = data40_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final40_1.csv"))
datasave50_1 = data50_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final50_1.csv"))
datasave60_1 = data60_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final60_1.csv"))
datasave70_1 = data70_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final70_1.csv"))
datasave80_1 = data80_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final80_1.csv"))
datasave90_1 = data90_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final90_1.csv"))
datasave100_1 = data100_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final100_1.csv"))

# %%
#[SIXTH BLOCK]
print(" This is for 0% CAV Penetration")
p0MVMV = data0_1.loc[data0_1['Interaction_Type'] == 0]
p0MVAV = data0_1.loc[data0_1['Interaction_Type'] == 1]
p0AVMV = data0_1.loc[data0_1['Interaction_Type'] == 2]
p0AVAV = data0_1.loc[data0_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p0MVMV))
print("MV-AV")
print(len(p0MVAV))
print("AV-MV")
print(len(p0AVMV))
print("AV-AV")
print(len(p0AVAV))


print(" This is for 10% CAV Penetration")

p10MVMV = data10_1.loc[data10_1['Interaction_Type'] == 0]
p10MVAV = data10_1.loc[data10_1['Interaction_Type'] == 1]
p10AVMV = data10_1.loc[data10_1['Interaction_Type'] == 2]
p10AVAV = data10_1.loc[data10_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p10MVMV))
print("MV-AV")
print(len(p10MVAV))
print("AV-MV")
print(len(p10AVMV))
print("AV-AV")
print(len(p10AVAV))

print(" This is for 20% CAV Penetration")

p20MVMV = data20_1.loc[data20_1['Interaction_Type'] == 0]
p20MVAV = data20_1.loc[data20_1['Interaction_Type'] == 1]
p20AVMV = data20_1.loc[data20_1['Interaction_Type'] == 2]
p20AVAV = data20_1.loc[data20_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p20MVMV))
print("MV-AV")
print(len(p20MVAV))
print("AV-MV")
print(len(p20AVMV))
print("AV-AV")
print(len(p20AVAV))

print(" This is for 30% CAV Penetration")

p30MVMV = data30_1.loc[data30_1['Interaction_Type'] == 0]
p30MVAV = data30_1.loc[data30_1['Interaction_Type'] == 1]
p30AVMV = data30_1.loc[data30_1['Interaction_Type'] == 2]
p30AVAV = data30_1.loc[data30_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p30MVMV))
print("MV-AV")
print(len(p30MVAV))
print("AV-MV")
print(len(p30AVMV))
print("AV-AV")
print(len(p30AVAV))

print(" This is for 40% CAV Penetration")

p40MVMV = data40_1.loc[data40_1['Interaction_Type'] == 0]
p40MVAV = data40_1.loc[data40_1['Interaction_Type'] == 1]
p40AVMV = data40_1.loc[data40_1['Interaction_Type'] == 2]
p40AVAV = data40_1.loc[data40_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p40MVMV))
print("MV-AV")
print(len(p40MVAV))
print("AV-MV")
print(len(p40AVMV))
print("AV-AV")
print(len(p40AVAV))

print(" This is for 50% CAV Penetration")

p50MVMV = data50_1.loc[data50_1['Interaction_Type'] == 0]
p50MVAV = data50_1.loc[data50_1['Interaction_Type'] == 1]
p50AVMV = data50_1.loc[data50_1['Interaction_Type'] == 2]
p50AVAV = data50_1.loc[data50_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p50MVMV))
print("MV-AV")
print(len(p50MVAV))
print("AV-MV")
print(len(p50AVMV))
print("AV-AV")
print(len(p50AVAV))

print(" This is for 60% CAV Penetration")

p60MVMV = data60_1.loc[data60_1['Interaction_Type'] == 0]
p60MVAV = data60_1.loc[data60_1['Interaction_Type'] == 1]
p60AVMV = data60_1.loc[data60_1['Interaction_Type'] == 2]
p60AVAV = data60_1.loc[data60_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p60MVMV))
print("MV-AV")
print(len(p60MVAV))
print("AV-MV")
print(len(p60AVMV))
print("AV-AV")
print(len(p60AVAV))

print(" This is for 70% CAV Penetration")

p70MVMV = data70_1.loc[data70_1['Interaction_Type'] == 0]
p70MVAV = data70_1.loc[data70_1['Interaction_Type'] == 1]
p70AVMV = data70_1.loc[data70_1['Interaction_Type'] == 2]
p70AVAV = data70_1.loc[data70_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p70MVMV))
print("MV-AV")
print(len(p70MVAV))
print("AV-MV")
print(len(p70AVMV))
print("AV-AV")
print(len(p70AVAV))

print(" This is for 80% CAV Penetration")

p80MVMV = data80_1.loc[data80_1['Interaction_Type'] == 0]
p80MVAV = data80_1.loc[data80_1['Interaction_Type'] == 1]
p80AVMV = data80_1.loc[data80_1['Interaction_Type'] == 2]
p80AVAV = data80_1.loc[data80_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p80MVMV))
print("MV-AV")
print(len(p80MVAV))
print("AV-MV")
print(len(p80AVMV))
print("AV-AV")
print(len(p80AVAV))

print(" This is for 90% CAV Penetration")

p90MVMV = data90_1.loc[data90_1['Interaction_Type'] == 0]
p90MVAV = data90_1.loc[data90_1['Interaction_Type'] == 1]
p90AVMV = data90_1.loc[data90_1['Interaction_Type'] == 2]
p90AVAV = data90_1.loc[data90_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p90MVMV))
print("MV-AV")
print(len(p90MVAV))
print("AV-MV")
print(len(p90AVMV))
print("AV-AV")
print(len(p90AVAV))

print(" This is for 100% CAV Penetration")

p100MVMV = data100_1.loc[data0_1['Interaction_Type'] == 0]
p100MVAV = data100_1.loc[data0_1['Interaction_Type'] == 1]
p100AVMV = data100_1.loc[data0_1['Interaction_Type'] == 2]
p100AVAV = data100_1.loc[data0_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p100MVMV))
print("MV-AV")
print(len(p100MVAV))
print("AV-MV")
print(len(p100AVMV))
print("AV-AV")
print(len(p100AVAV))
# Out:
#  This is for 0% CAV Penetration
# MV-MV
# 7333
# MV-AV
# 0
# AV-MV
# 0
# AV-AV
# 0
#  This is for 10% CAV Penetration
# MV-MV
# 3024
# MV-AV
# 373
# AV-MV
# 381
# AV-AV
# 26
#  This is for 20% CAV Penetration
# MV-MV
# 1920
# MV-AV
# 525
# AV-MV
# 538
# AV-AV
# 146
#  This is for 30% CAV Penetration
# MV-MV
# 1211
# MV-AV
# 534
# AV-MV
# 506
# AV-AV
# 215
#  This is for 40% CAV Penetration
# MV-MV
# 946
# MV-AV
# 570
# AV-MV
# 564
# AV-AV
# 416
#  This is for 50% CAV Penetration
# MV-MV
# 676
# MV-AV
# 656
# AV-MV
# 663
# AV-AV
# 720
#  This is for 60% CAV Penetration
# MV-MV
# 425
# MV-AV
# 753
# AV-MV
# 699
# AV-AV
# 1007
#  This is for 70% CAV Penetration
# MV-MV
# 272
# MV-AV
# 583
# AV-MV
# 606
# AV-AV
# 1476
#  This is for 80% CAV Penetration
# MV-MV
# 125
# MV-AV
# 498
# AV-MV
# 535
# AV-AV
# 1987
#  This is for 90% CAV Penetration
# MV-MV
# 48
# MV-AV
# 291
# AV-MV
# 330
# AV-AV
# 2702
#  This is for 100% CAV Penetration
# MV-MV
# 3594
# MV-AV
# 0
# AV-MV
# 0
# AV-AV
# 0

# %%
#SEED2 - 11 Cases

# %%
#[first block]
df0_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000001_002.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df10_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000002_002.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df20_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000003_002.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df30_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000004_002.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df40_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000005_002.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df50_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000006_002.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df60_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000007_002.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df70_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000008_002.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df80_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000009_002.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df90_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000010_002.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df100_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000011_002.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)

# %%
#[SECOND BLOCLK]
f0_1 = df0_1.loc[df0_1['VehType'] == 100]
f1_0_1 = f0_1['VehNo']
g0_1 = df0_1.loc[df0_1['VehType'] == 101]
g1_0_1 = g0_1['VehNo']

f10_1 = df10_1.loc[df10_1['VehType'] == 100]
f1_10_1 = f10_1['VehNo']
g10_1 = df10_1.loc[df10_1['VehType'] == 101]
g1_10_1 = g10_1['VehNo']

f20_1 = df20_1.loc[df20_1['VehType'] == 100]
f1_20_1 = f20_1['VehNo']
g20_1 = df20_1.loc[df20_1['VehType'] == 101]
g1_20_1 = g20_1['VehNo']

f30_1 = df30_1.loc[df30_1['VehType'] == 100]
f1_30_1 = f30_1['VehNo']
g30_1 = df30_1.loc[df30_1['VehType'] == 101]
g1_30_1 = g30_1['VehNo']

f40_1 = df40_1.loc[df40_1['VehType'] == 100]
f1_40_1 = f40_1['VehNo']
g40_1 = df40_1.loc[df40_1['VehType'] == 101]
g1_40_1 = g40_1['VehNo']

f50_1 = df50_1.loc[df50_1['VehType'] == 100]
f1_50_1 = f50_1['VehNo']
g50_1 = df50_1.loc[df50_1['VehType'] == 101]
g1_50_1 = g50_1['VehNo']

f60_1 = df60_1.loc[df60_1['VehType'] == 100]
f1_60_1 = f60_1['VehNo']
g60_1 = df60_1.loc[df60_1['VehType'] == 101]
g1_60_1 = g60_1['VehNo']

f70_1 = df70_1.loc[df70_1['VehType'] == 100]
f1_70_1 = f70_1['VehNo']
g70_1 = df70_1.loc[df70_1['VehType'] == 101]
g1_70_1 = g70_1['VehNo']

f80_1 = df80_1.loc[df80_1['VehType'] == 100]
f1_80_1 = f80_1['VehNo']
g80_1 = df80_1.loc[df80_1['VehType'] == 101]
g1_80_1 = g80_1['VehNo']

f90_1 = df90_1.loc[df90_1['VehType'] == 100]
f1_90_1 = f90_1['VehNo']
g90_1 = df90_1.loc[df90_1['VehType'] == 101]
g1_90_1 = g90_1['VehNo']

f100_1 = df100_1.loc[df100_1['VehType'] == 100]
f1_100_1 = f100_1['VehNo']
g100_1 = df100_1.loc[df100_1['VehType'] == 101]
g1_100_1 = g100_1['VehNo']


f1save = f1_0_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual2.csv"))
g1save = g1_0_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV2.csv"))

f1save = f1_10_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual2.csv"))
g1save = g1_10_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV2.csv"))

f1save = f1_20_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual2.csv"))
g1save = g1_20_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV2.csv"))

f1save = f1_30_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual2.csv"))
g1save = g1_30_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV2.csv"))

f1save = f1_40_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual2.csv"))
g1save = g1_40_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV2.csv"))

f1save = f1_50_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual2.csv"))
g1save = g1_50_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV2.csv"))

f1save = f1_60_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual2.csv"))
g1save = g1_60_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV2.csv"))

f1save = f1_70_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual2.csv"))
g1save = g1_70_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV2.csv"))

f1save = f1_80_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual2.csv"))
g1save = g1_80_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV2.csv"))

f1save = f1_90_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual2.csv"))
g1save = g1_90_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV2.csv"))

f1save =f1_100_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual2.csv"))
g1save =g1_100_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV2.csv"))



print("0%")
print(len(f1_0_1))
print(len(g1_0_1))
print(len(g1_0_1)+len(f1_0_1))
print(len(df0_1))
      
print("Next Scenario --> MV --> AV --> total")
print("10%")
print(len(f1_10_1))
print(len(g1_10_1))
print(len(g1_10_1)+len(f1_10_1))
print(len(df10_1))
print("Next Scenario --> MV --> AV --> total")
print("20%")
print(len(f1_20_1))
print(len(g1_20_1))
print(len(g1_20_1)+len(f1_20_1))
print(len(df20_1))
print("Next Scenario --> MV --> AV --> total")
print("30%")
print(len(f1_30_1))
print(len(g1_30_1))
print(len(g1_30_1)+len(f1_30_1))
print(len(df30_1))
print("Next Scenario --> MV --> AV --> total")
print("40%")
print(len(f1_40_1))
print(len(g1_40_1))
print(len(g1_40_1)+len(f1_40_1))
print(len(df40_1))
print("Next Scenario --> MV --> AV --> total")
print("50%")
print(len(f1_50_1))
print(len(g1_50_1))
print(len(g1_50_1)+len(f1_50_1))
print(len(df50_1))
print("Next Scenario --> MV --> AV --> total")
print("60%")
print(len(f1_60_1))
print(len(g1_60_1))
print(len(g1_60_1)+len(f1_60_1))
print(len(df60_1))
print("Next Scenario --> MV --> AV --> total")
print("70%")
print(len(f1_70_1))
print(len(g1_70_1))
print(len(g1_70_1)+len(f1_70_1))
print(len(df70_1))
print("Next Scenario --> MV --> AV --> total")
print("80%")
print(len(f1_80_1))
print(len(g1_80_1))
print(len(g1_80_1)+len(f1_80_1))
print(len(df80_1))
print("Next Scenario --> MV --> AV --> total")
print("90%")
print(len(f1_90_1))
print(len(g1_90_1))
print(len(g1_90_1)+len(f1_90_1))
print(len(df90_1))
print("Next Scenario --> MV --> AV --> total")
print("100%")
print(len(f1_100_1))
print(len(g1_100_1))
print(len(g1_100_1)+len(f1_100_1))
print(len(df100_1))
print("Next Scenario --> MV --> AV --> total")
# Out:
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:58: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:59: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:61: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ...

# %%
#[THIRD BLOCK]
#reading the SSAM file 
data0_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000001_002TRJ.csv', delimiter = ',', header = 0)
length0_1 = len(data0_1)
print(length0_1)

data10_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000002_002TRJ.csv', delimiter = ',', header = 0)
length10_1 = len(data10_1)
print(length10_1)

data20_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000003_002TRJ.csv', delimiter = ',', header = 0)
length20_1 = len(data20_1)
print(length20_1)

data30_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000004_002TRJ.csv', delimiter = ',', header = 0)
length30_1 = len(data30_1)
print(length30_1)

data40_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000005_002TRJ.csv', delimiter = ',', header = 0)
length40_1 = len(data40_1)
print(length40_1)

data50_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000006_002TRJ.csv', delimiter = ',', header = 0)
length50_1 = len(data50_1)
print(length50_1)

data60_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000007_002TRJ.csv', delimiter = ',', header = 0)
length60_1 = len(data60_1)
print(length60_1)

data70_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000008_002TRJ.csv', delimiter = ',', header = 0)
length70_1 = len(data70_1)
print(length70_1)

data80_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000009_002TRJ.csv', delimiter = ',', header = 0)
length80_1 = len(data80_1)
print(length80_1)

data90_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000010_002TRJ.csv', delimiter = ',', header = 0)
length90_1 = len(data90_1)
print(length90_1)

data100_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000011_002TRJ.csv', delimiter = ',', header = 0)
length100_1 = len(data100_1)
print(length100_1)


#Append new coloumn
data0_1["Interaction_Type"] = ""
data10_1["Interaction_Type"] = ""
data20_1["Interaction_Type"] = ""
data30_1["Interaction_Type"] = ""
data40_1["Interaction_Type"] = ""
data50_1["Interaction_Type"] = ""
data60_1["Interaction_Type"] = ""
data70_1["Interaction_Type"] = ""
data80_1["Interaction_Type"] = ""
data90_1["Interaction_Type"] = ""
data100_1["Interaction_Type"] = ""
# Out:
# 7354
# 3551
# 2796
# 2480
# 2511
# 2704
# 2891
# 2990
# 3181
# 3475
# 3706

# %%
#[FOURTH BLOCK]
for i in range (0, length0_1):
    if(data0_1.FirstVID[i] in (f1_0_1)) and (data0_1.SecondVID[i] in (f1_0_1)):
        data0_1.Interaction_Type[i] = 0
        
    elif(data0_1.FirstVID[i] in (f1_0_1)) and (data0_1.SecondVID[i] in (g1_0_1)):
        data0_1.Interaction_Type[i] = 1
        
    elif(data0_1.FirstVID[i] in (g1_0_1)) and (data0_1.SecondVID[i] in (f1_0_1)):
        data0_1.Interaction_Type[i] = 2
        
    elif(data0_1.FirstVID[i] in (g1_0_1)) and (data0_1.SecondVID[i] in (g1_0_1)):
        data0_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("0% done")   


for i in range (0, length10_1):
    if(data10_1.FirstVID[i] in (f1_10_1)) and (data10_1.SecondVID[i] in (f1_10_1)):
        data10_1.Interaction_Type[i] = 0
        
    elif(data10_1.FirstVID[i] in (f1_10_1)) and (data10_1.SecondVID[i] in (g1_10_1)):
        data10_1.Interaction_Type[i] = 1
        
    elif(data10_1.FirstVID[i] in (g1_10_1)) and (data10_1.SecondVID[i] in (f1_10_1)):
        data10_1.Interaction_Type[i] = 2
        
    elif(data10_1.FirstVID[i] in (g1_10_1)) and (data10_1.SecondVID[i] in (g1_10_1)):
        data10_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("10% done") 


for i in range (0, length20_1):
    if(data20_1.FirstVID[i] in (f1_20_1)) and (data20_1.SecondVID[i] in (f1_20_1)):
        data20_1.Interaction_Type[i] = 0
        
    elif(data20_1.FirstVID[i] in (f1_20_1)) and (data20_1.SecondVID[i] in (g1_20_1)):
        data20_1.Interaction_Type[i] = 1
        
    elif(data20_1.FirstVID[i] in (g1_20_1)) and (data20_1.SecondVID[i] in (f1_20_1)):
        data20_1.Interaction_Type[i] = 2
        
    elif(data20_1.FirstVID[i] in (g1_20_1)) and (data20_1.SecondVID[i] in (g1_20_1)):
        data20_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("20% done") 



for i in range (0, length30_1):
    if(data30_1.FirstVID[i] in (f1_30_1)) and (data30_1.SecondVID[i] in (f1_30_1)):
        data30_1.Interaction_Type[i] = 0
        
    elif(data30_1.FirstVID[i] in (f1_30_1)) and (data30_1.SecondVID[i] in (g1_30_1)):
        data30_1.Interaction_Type[i] = 1
        
    elif(data30_1.FirstVID[i] in (g1_30_1)) and (data30_1.SecondVID[i] in (f1_30_1)):
        data30_1.Interaction_Type[i] = 2
        
    elif(data30_1.FirstVID[i] in (g1_30_1)) and (data30_1.SecondVID[i] in (g1_30_1)):
        data30_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("30% done") 



for i in range (0, length40_1):
    if(data40_1.FirstVID[i] in (f1_40_1)) and (data40_1.SecondVID[i] in (f1_40_1)):
        data40_1.Interaction_Type[i] = 0
        
    elif(data40_1.FirstVID[i] in (f1_40_1)) and (data40_1.SecondVID[i] in (g1_40_1)):
        data40_1.Interaction_Type[i] = 1
        
    elif(data40_1.FirstVID[i] in (g1_40_1)) and (data40_1.SecondVID[i] in (f1_40_1)):
        data40_1.Interaction_Type[i] = 2
        
    elif(data40_1.FirstVID[i] in (g1_40_1)) and (data40_1.SecondVID[i] in (g1_40_1)):
        data40_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("40% done") 



for i in range (0, length50_1):
    if(data50_1.FirstVID[i] in (f1_50_1)) and (data50_1.SecondVID[i] in (f1_50_1)):
        data50_1.Interaction_Type[i] = 0
        
    elif(data50_1.FirstVID[i] in (f1_50_1)) and (data50_1.SecondVID[i] in (g1_50_1)):
        data50_1.Interaction_Type[i] = 1
        
    elif(data50_1.FirstVID[i] in (g1_50_1)) and (data50_1.SecondVID[i] in (f1_50_1)):
        data50_1.Interaction_Type[i] = 2
        
    elif(data50_1.FirstVID[i] in (g1_50_1)) and (data50_1.SecondVID[i] in (g1_50_1)):
        data50_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("50% done") 




for i in range (0, length60_1):
    if(data60_1.FirstVID[i] in (f1_60_1)) and (data60_1.SecondVID[i] in (f1_60_1)):
        data60_1.Interaction_Type[i] = 0
        
    elif(data60_1.FirstVID[i] in (f1_60_1)) and (data60_1.SecondVID[i] in (g1_60_1)):
        data60_1.Interaction_Type[i] = 1
        
    elif(data60_1.FirstVID[i] in (g1_60_1)) and (data60_1.SecondVID[i] in (f1_60_1)):
        data60_1.Interaction_Type[i] = 2
        
    elif(data60_1.FirstVID[i] in (g1_60_1)) and (data60_1.SecondVID[i] in (g1_60_1)):
        data60_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("60% done") 



for i in range (0, length70_1):
    if(data70_1.FirstVID[i] in (f1_70_1)) and (data70_1.SecondVID[i] in (f1_70_1)):
        data70_1.Interaction_Type[i] = 0
        
    elif(data70_1.FirstVID[i] in (f1_70_1)) and (data70_1.SecondVID[i] in (g1_70_1)):
        data70_1.Interaction_Type[i] = 1
        
    elif(data70_1.FirstVID[i] in (g1_70_1)) and (data70_1.SecondVID[i] in (f1_70_1)):
        data70_1.Interaction_Type[i] = 2
        
    elif(data70_1.FirstVID[i] in (g1_70_1)) and (data70_1.SecondVID[i] in (g1_70_1)):
        data70_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("70% done") 



for i in range (0, length80_1):
    if(data80_1.FirstVID[i] in (f1_80_1)) and (data80_1.SecondVID[i] in (f1_80_1)):
        data80_1.Interaction_Type[i] = 0
        
    elif(data80_1.FirstVID[i] in (f1_80_1)) and (data80_1.SecondVID[i] in (g1_80_1)):
        data80_1.Interaction_Type[i] = 1
        
    elif(data80_1.FirstVID[i] in (g1_80_1)) and (data80_1.SecondVID[i] in (f1_80_1)):
        data80_1.Interaction_Type[i] = 2
        
    elif(data80_1.FirstVID[i] in (g1_80_1)) and (data80_1.SecondVID[i] in (g1_80_1)):
        data80_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("80% done") 




for i in range (0, length90_1):
    if(data90_1.FirstVID[i] in (f1_90_1)) and (data90_1.SecondVID[i] in (f1_90_1)):
        data90_1.Interaction_Type[i] = 0
        
    elif(data90_1.FirstVID[i] in (f1_90_1)) and (data90_1.SecondVID[i] in (g1_90_1)):
        data90_1.Interaction_Type[i] = 1
        
    elif(data90_1.FirstVID[i] in (g1_90_1)) and (data90_1.SecondVID[i] in (f1_90_1)):
        data90_1.Interaction_Type[i] = 2
        
    elif(data90_1.FirstVID[i] in (g1_90_1)) and (data90_1.SecondVID[i] in (g1_90_1)):
        data90_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("90% done") 




for i in range (0, length100_1):
    if(data100_1.FirstVID[i] in (f1_100_1)) and (data100_1.SecondVID[i] in (f1_100_1)):
        data100_1.Interaction_Type[i] = 0
        
    elif(data100_1.FirstVID[i] in (f1_100_1)) and (data100_1.SecondVID[i] in (g1_100_1)):
        data100_1.Interaction_Type[i] = 1
        
    elif(data100_1.FirstVID[i] in (g1_100_1)) and (data100_1.SecondVID[i] in (f1_100_1)):
        data100_1.Interaction_Type[i] = 2
        
    elif(data100_1.FirstVID[i] in (g1_100_1)) and (data100_1.SecondVID[i] in (g1_100_1)):
        data100_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("100% done")
# Out:
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 0% done
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
#[FIFTH BLOCK]
datasave0_1 = data0_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final0_2.csv"))
datasave10_1 = data10_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final10_2.csv"))
datasave20_1 = data20_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final20_2.csv"))
datasave30_1 = data30_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final30_2.csv"))
datasave40_1 = data40_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final40_2.csv"))
datasave50_1 = data50_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final50_2.csv"))
datasave60_1 = data60_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final60_2.csv"))
datasave70_1 = data70_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final70_2.csv"))
datasave80_1 = data80_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final80_2.csv"))
datasave90_1 = data90_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final90_2.csv"))
datasave100_1 = data100_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final100_2.csv"))

# %%
#[SIXTH BLOCK]
print(" This is for 0% CAV Penetration")
p0MVMV = data0_1.loc[data0_1['Interaction_Type'] == 0]
p0MVAV = data0_1.loc[data0_1['Interaction_Type'] == 1]
p0AVMV = data0_1.loc[data0_1['Interaction_Type'] == 2]
p0AVAV = data0_1.loc[data0_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p0MVMV))
print("MV-AV")
print(len(p0MVAV))
print("AV-MV")
print(len(p0AVMV))
print("AV-AV")
print(len(p0AVAV))


print(" This is for 10% CAV Penetration")

p10MVMV = data10_1.loc[data10_1['Interaction_Type'] == 0]
p10MVAV = data10_1.loc[data10_1['Interaction_Type'] == 1]
p10AVMV = data10_1.loc[data10_1['Interaction_Type'] == 2]
p10AVAV = data10_1.loc[data10_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p10MVMV))
print("MV-AV")
print(len(p10MVAV))
print("AV-MV")
print(len(p10AVMV))
print("AV-AV")
print(len(p10AVAV))

print(" This is for 20% CAV Penetration")

p20MVMV = data20_1.loc[data20_1['Interaction_Type'] == 0]
p20MVAV = data20_1.loc[data20_1['Interaction_Type'] == 1]
p20AVMV = data20_1.loc[data20_1['Interaction_Type'] == 2]
p20AVAV = data20_1.loc[data20_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p20MVMV))
print("MV-AV")
print(len(p20MVAV))
print("AV-MV")
print(len(p20AVMV))
print("AV-AV")
print(len(p20AVAV))

print(" This is for 30% CAV Penetration")

p30MVMV = data30_1.loc[data30_1['Interaction_Type'] == 0]
p30MVAV = data30_1.loc[data30_1['Interaction_Type'] == 1]
p30AVMV = data30_1.loc[data30_1['Interaction_Type'] == 2]
p30AVAV = data30_1.loc[data30_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p30MVMV))
print("MV-AV")
print(len(p30MVAV))
print("AV-MV")
print(len(p30AVMV))
print("AV-AV")
print(len(p30AVAV))

print(" This is for 40% CAV Penetration")

p40MVMV = data40_1.loc[data40_1['Interaction_Type'] == 0]
p40MVAV = data40_1.loc[data40_1['Interaction_Type'] == 1]
p40AVMV = data40_1.loc[data40_1['Interaction_Type'] == 2]
p40AVAV = data40_1.loc[data40_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p40MVMV))
print("MV-AV")
print(len(p40MVAV))
print("AV-MV")
print(len(p40AVMV))
print("AV-AV")
print(len(p40AVAV))

print(" This is for 50% CAV Penetration")

p50MVMV = data50_1.loc[data50_1['Interaction_Type'] == 0]
p50MVAV = data50_1.loc[data50_1['Interaction_Type'] == 1]
p50AVMV = data50_1.loc[data50_1['Interaction_Type'] == 2]
p50AVAV = data50_1.loc[data50_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p50MVMV))
print("MV-AV")
print(len(p50MVAV))
print("AV-MV")
print(len(p50AVMV))
print("AV-AV")
print(len(p50AVAV))

print(" This is for 60% CAV Penetration")

p60MVMV = data60_1.loc[data60_1['Interaction_Type'] == 0]
p60MVAV = data60_1.loc[data60_1['Interaction_Type'] == 1]
p60AVMV = data60_1.loc[data60_1['Interaction_Type'] == 2]
p60AVAV = data60_1.loc[data60_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p60MVMV))
print("MV-AV")
print(len(p60MVAV))
print("AV-MV")
print(len(p60AVMV))
print("AV-AV")
print(len(p60AVAV))

print(" This is for 70% CAV Penetration")

p70MVMV = data70_1.loc[data70_1['Interaction_Type'] == 0]
p70MVAV = data70_1.loc[data70_1['Interaction_Type'] == 1]
p70AVMV = data70_1.loc[data70_1['Interaction_Type'] == 2]
p70AVAV = data70_1.loc[data70_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p70MVMV))
print("MV-AV")
print(len(p70MVAV))
print("AV-MV")
print(len(p70AVMV))
print("AV-AV")
print(len(p70AVAV))

print(" This is for 80% CAV Penetration")

p80MVMV = data80_1.loc[data80_1['Interaction_Type'] == 0]
p80MVAV = data80_1.loc[data80_1['Interaction_Type'] == 1]
p80AVMV = data80_1.loc[data80_1['Interaction_Type'] == 2]
p80AVAV = data80_1.loc[data80_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p80MVMV))
print("MV-AV")
print(len(p80MVAV))
print("AV-MV")
print(len(p80AVMV))
print("AV-AV")
print(len(p80AVAV))

print(" This is for 90% CAV Penetration")

p90MVMV = data90_1.loc[data90_1['Interaction_Type'] == 0]
p90MVAV = data90_1.loc[data90_1['Interaction_Type'] == 1]
p90AVMV = data90_1.loc[data90_1['Interaction_Type'] == 2]
p90AVAV = data90_1.loc[data90_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p90MVMV))
print("MV-AV")
print(len(p90MVAV))
print("AV-MV")
print(len(p90AVMV))
print("AV-AV")
print(len(p90AVAV))

print(" This is for 100% CAV Penetration")

p100MVMV = data100_1.loc[data0_1['Interaction_Type'] == 0]
p100MVAV = data100_1.loc[data0_1['Interaction_Type'] == 1]
p100AVMV = data100_1.loc[data0_1['Interaction_Type'] == 2]
p100AVAV = data100_1.loc[data0_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p100MVMV))
print("MV-AV")
print(len(p100MVAV))
print("AV-MV")
print(len(p100AVMV))
print("AV-AV")
print(len(p100AVAV))
# Out:
#  This is for 0% CAV Penetration
# MV-MV
# 7354
# MV-AV
# 0
# AV-MV
# 0
# AV-AV
# 0
#  This is for 10% CAV Penetration
# MV-MV
# 2862
# MV-AV
# 326
# AV-MV
# 339
# AV-AV
# 24
#  This is for 20% CAV Penetration
# MV-MV
# 1706
# MV-AV
# 464
# AV-MV
# 496
# AV-AV
# 130
#  This is for 30% CAV Penetration
# MV-MV
# 1230
# MV-AV
# 528
# AV-MV
# 483
# AV-AV
# 239
#  This is for 40% CAV Penetration
# MV-MV
# 926
# MV-AV
# 623
# AV-MV
# 562
# AV-AV
# 400
#  This is for 50% CAV Penetration
# MV-MV
# 669
# MV-AV
# 693
# AV-MV
# 647
# AV-AV
# 695
#  This is for 60% CAV Penetration
# MV-MV
# 456
# MV-AV
# 720
# AV-MV
# 713
# AV-AV
# 1002
#  This is for 70% CAV Penetration
# MV-MV
# 262
# MV-AV
# 673
# AV-MV
# 620
# AV-AV
# 1435
#  This is for 80% CAV Penetration
# MV-MV
# 113
# MV-AV
# 542
# AV-MV
# 515
# AV-AV
# 2011
#  This is for 90% CAV Penetration
# MV-MV
# 39
# MV-AV
# 317
# AV-MV
# 302
# AV-AV
# 2817
#  This is for 100% CAV Penetration
# MV-MV
# 3706
# MV-AV
# 0
# AV-MV
# 0
# AV-AV
# 0

# %%
#seed3 11 cases

# %%
#[First block]
df0_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000001_003.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df10_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000002_003.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df20_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000003_003.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df30_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000004_003.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df40_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000005_003.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df50_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000006_003.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df60_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000007_003.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df70_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000008_003.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df80_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000009_003.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df90_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000010_003.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)
df100_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000011_003.csv', delimiter = ';', names = ['Time','Link','Lane', 'VehNo','VehType', 'Line', 'DesSpeed', 'Nan'], dtype = {'Time' : float, 'Link' : float, 'Lane' : float, 'VehNo' : float, 'VehType' : float,'Line' : float, 'DesSpeed' : float }, skiprows =1)

# %%
#[SECOND BLOCLK]
f0_1 = df0_1.loc[df0_1['VehType'] == 100]
f1_0_1 = f0_1['VehNo']
g0_1 = df0_1.loc[df0_1['VehType'] == 101]
g1_0_1 = g0_1['VehNo']

f10_1 = df10_1.loc[df10_1['VehType'] == 100]
f1_10_1 = f10_1['VehNo']
g10_1 = df10_1.loc[df10_1['VehType'] == 101]
g1_10_1 = g10_1['VehNo']

f20_1 = df20_1.loc[df20_1['VehType'] == 100]
f1_20_1 = f20_1['VehNo']
g20_1 = df20_1.loc[df20_1['VehType'] == 101]
g1_20_1 = g20_1['VehNo']

f30_1 = df30_1.loc[df30_1['VehType'] == 100]
f1_30_1 = f30_1['VehNo']
g30_1 = df30_1.loc[df30_1['VehType'] == 101]
g1_30_1 = g30_1['VehNo']

f40_1 = df40_1.loc[df40_1['VehType'] == 100]
f1_40_1 = f40_1['VehNo']
g40_1 = df40_1.loc[df40_1['VehType'] == 101]
g1_40_1 = g40_1['VehNo']

f50_1 = df50_1.loc[df50_1['VehType'] == 100]
f1_50_1 = f50_1['VehNo']
g50_1 = df50_1.loc[df50_1['VehType'] == 101]
g1_50_1 = g50_1['VehNo']

f60_1 = df60_1.loc[df60_1['VehType'] == 100]
f1_60_1 = f60_1['VehNo']
g60_1 = df60_1.loc[df60_1['VehType'] == 101]
g1_60_1 = g60_1['VehNo']

f70_1 = df70_1.loc[df70_1['VehType'] == 100]
f1_70_1 = f70_1['VehNo']
g70_1 = df70_1.loc[df70_1['VehType'] == 101]
g1_70_1 = g70_1['VehNo']

f80_1 = df80_1.loc[df80_1['VehType'] == 100]
f1_80_1 = f80_1['VehNo']
g80_1 = df80_1.loc[df80_1['VehType'] == 101]
g1_80_1 = g80_1['VehNo']

f90_1 = df90_1.loc[df90_1['VehType'] == 100]
f1_90_1 = f90_1['VehNo']
g90_1 = df90_1.loc[df90_1['VehType'] == 101]
g1_90_1 = g90_1['VehNo']

f100_1 = df100_1.loc[df100_1['VehType'] == 100]
f1_100_1 = f100_1['VehNo']
g100_1 = df100_1.loc[df100_1['VehType'] == 101]
g1_100_1 = g100_1['VehNo']


f1save = f1_0_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual3.csv"))
g1save = g1_0_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV3.csv"))

f1save = f1_10_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual3.csv"))
g1save = g1_10_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV3.csv"))

f1save = f1_20_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual3.csv"))
g1save = g1_20_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV3.csv"))

f1save = f1_30_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual3.csv"))
g1save = g1_30_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV3.csv"))

f1save = f1_40_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual3.csv"))
g1save = g1_40_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV3.csv"))

f1save = f1_50_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual3.csv"))
g1save = g1_50_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV3.csv"))

f1save = f1_60_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual3.csv"))
g1save = g1_60_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV3.csv"))

f1save = f1_70_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual3.csv"))
g1save = g1_70_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV3.csv"))

f1save = f1_80_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual3.csv"))
g1save = g1_80_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV3.csv"))

f1save = f1_90_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual3.csv"))
g1save = g1_90_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV3.csv"))

f1save =f1_100_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Manual3.csv"))
g1save =g1_100_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\CAV3.csv"))



print("0%")
print(len(f1_0_1))
print(len(g1_0_1))
print(len(g1_0_1)+len(f1_0_1))
print(len(df0_1))
      
print("Next Scenario --> MV --> AV --> total")
print("10%")
print(len(f1_10_1))
print(len(g1_10_1))
print(len(g1_10_1)+len(f1_10_1))
print(len(df10_1))
print("Next Scenario --> MV --> AV --> total")
print("20%")
print(len(f1_20_1))
print(len(g1_20_1))
print(len(g1_20_1)+len(f1_20_1))
print(len(df20_1))
print("Next Scenario --> MV --> AV --> total")
print("30%")
print(len(f1_30_1))
print(len(g1_30_1))
print(len(g1_30_1)+len(f1_30_1))
print(len(df30_1))
print("Next Scenario --> MV --> AV --> total")
print("40%")
print(len(f1_40_1))
print(len(g1_40_1))
print(len(g1_40_1)+len(f1_40_1))
print(len(df40_1))
print("Next Scenario --> MV --> AV --> total")
print("50%")
print(len(f1_50_1))
print(len(g1_50_1))
print(len(g1_50_1)+len(f1_50_1))
print(len(df50_1))
print("Next Scenario --> MV --> AV --> total")
print("60%")
print(len(f1_60_1))
print(len(g1_60_1))
print(len(g1_60_1)+len(f1_60_1))
print(len(df60_1))
print("Next Scenario --> MV --> AV --> total")
print("70%")
print(len(f1_70_1))
print(len(g1_70_1))
print(len(g1_70_1)+len(f1_70_1))
print(len(df70_1))
print("Next Scenario --> MV --> AV --> total")
print("80%")
print(len(f1_80_1))
print(len(g1_80_1))
print(len(g1_80_1)+len(f1_80_1))
print(len(df80_1))
print("Next Scenario --> MV --> AV --> total")
print("90%")
print(len(f1_90_1))
print(len(g1_90_1))
print(len(g1_90_1)+len(f1_90_1))
print(len(df90_1))
print("Next Scenario --> MV --> AV --> total")
print("100%")
print(len(f1_100_1))
print(len(g1_100_1))
print(len(g1_100_1)+len(f1_100_1))
print(len(df100_1))
print("Next Scenario --> MV --> AV --> total")
# Out:
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:58: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:59: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:61: FutureWarning: The signature of `Series.to_csv` was aligned to that of `DataFrame.to_csv`, and argument 'header' will change its default value from False to True: please pass an explicit value to suppress this warning.
# ...

# %%
#[THIRD BLOCK]
#reading the SSAM file 
data0_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000001_003TRJ.csv', delimiter = ',', header = 0)
length0_1 = len(data0_1)
print(length0_1)

data10_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000002_003TRJ.csv', delimiter = ',', header = 0)
length10_1 = len(data10_1)
print(length10_1)

data20_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000003_003TRJ.csv', delimiter = ',', header = 0)
length20_1 = len(data20_1)
print(length20_1)

data30_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000004_003TRJ.csv', delimiter = ',', header = 0)
length30_1 = len(data30_1)
print(length30_1)

data40_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000005_003TRJ.csv', delimiter = ',', header = 0)
length40_1 = len(data40_1)
print(length40_1)

data50_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000006_003TRJ.csv', delimiter = ',', header = 0)
length50_1 = len(data50_1)
print(length50_1)

data60_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000007_003TRJ.csv', delimiter = ',', header = 0)
length60_1 = len(data60_1)
print(length60_1)

data70_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000008_003TRJ.csv', delimiter = ',', header = 0)
length70_1 = len(data70_1)
print(length70_1)

data80_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000009_003TRJ.csv', delimiter = ',', header = 0)
length80_1 = len(data80_1)
print(length80_1)

data90_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000010_003.csv', delimiter = ',', header = 0)
length90_1 = len(data90_1)
print(length90_1)

data100_1 = pd.read_csv('D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\S000011_003.csv', delimiter = ',', header = 0)
length100_1 = len(data100_1)
print(length100_1)


#Append new coloumn
data0_1["Interaction_Type"] = ""
data10_1["Interaction_Type"] = ""
data20_1["Interaction_Type"] = ""
data30_1["Interaction_Type"] = ""
data40_1["Interaction_Type"] = ""
data50_1["Interaction_Type"] = ""
data60_1["Interaction_Type"] = ""
data70_1["Interaction_Type"] = ""
data80_1["Interaction_Type"] = ""
data90_1["Interaction_Type"] = ""
data100_1["Interaction_Type"] = ""
# Out:
# 7563
# 3708
# 2804
# 2560
# 2592
# 2664
# 2785
# 2995
# 3311
# 3570
# 3809

# %%
#[FOURTH BLOCK]
for i in range (0, length0_1):
    if(data0_1.FirstVID[i] in (f1_0_1)) and (data0_1.SecondVID[i] in (f1_0_1)):
        data0_1.Interaction_Type[i] = 0
        
    elif(data0_1.FirstVID[i] in (f1_0_1)) and (data0_1.SecondVID[i] in (g1_0_1)):
        data0_1.Interaction_Type[i] = 1
        
    elif(data0_1.FirstVID[i] in (g1_0_1)) and (data0_1.SecondVID[i] in (f1_0_1)):
        data0_1.Interaction_Type[i] = 2
        
    elif(data0_1.FirstVID[i] in (g1_0_1)) and (data0_1.SecondVID[i] in (g1_0_1)):
        data0_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("0% done")   


for i in range (0, length10_1):
    if(data10_1.FirstVID[i] in (f1_10_1)) and (data10_1.SecondVID[i] in (f1_10_1)):
        data10_1.Interaction_Type[i] = 0
        
    elif(data10_1.FirstVID[i] in (f1_10_1)) and (data10_1.SecondVID[i] in (g1_10_1)):
        data10_1.Interaction_Type[i] = 1
        
    elif(data10_1.FirstVID[i] in (g1_10_1)) and (data10_1.SecondVID[i] in (f1_10_1)):
        data10_1.Interaction_Type[i] = 2
        
    elif(data10_1.FirstVID[i] in (g1_10_1)) and (data10_1.SecondVID[i] in (g1_10_1)):
        data10_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("10% done") 


for i in range (0, length20_1):
    if(data20_1.FirstVID[i] in (f1_20_1)) and (data20_1.SecondVID[i] in (f1_20_1)):
        data20_1.Interaction_Type[i] = 0
        
    elif(data20_1.FirstVID[i] in (f1_20_1)) and (data20_1.SecondVID[i] in (g1_20_1)):
        data20_1.Interaction_Type[i] = 1
        
    elif(data20_1.FirstVID[i] in (g1_20_1)) and (data20_1.SecondVID[i] in (f1_20_1)):
        data20_1.Interaction_Type[i] = 2
        
    elif(data20_1.FirstVID[i] in (g1_20_1)) and (data20_1.SecondVID[i] in (g1_20_1)):
        data20_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("20% done") 



for i in range (0, length30_1):
    if(data30_1.FirstVID[i] in (f1_30_1)) and (data30_1.SecondVID[i] in (f1_30_1)):
        data30_1.Interaction_Type[i] = 0
        
    elif(data30_1.FirstVID[i] in (f1_30_1)) and (data30_1.SecondVID[i] in (g1_30_1)):
        data30_1.Interaction_Type[i] = 1
        
    elif(data30_1.FirstVID[i] in (g1_30_1)) and (data30_1.SecondVID[i] in (f1_30_1)):
        data30_1.Interaction_Type[i] = 2
        
    elif(data30_1.FirstVID[i] in (g1_30_1)) and (data30_1.SecondVID[i] in (g1_30_1)):
        data30_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("30% done") 



for i in range (0, length40_1):
    if(data40_1.FirstVID[i] in (f1_40_1)) and (data40_1.SecondVID[i] in (f1_40_1)):
        data40_1.Interaction_Type[i] = 0
        
    elif(data40_1.FirstVID[i] in (f1_40_1)) and (data40_1.SecondVID[i] in (g1_40_1)):
        data40_1.Interaction_Type[i] = 1
        
    elif(data40_1.FirstVID[i] in (g1_40_1)) and (data40_1.SecondVID[i] in (f1_40_1)):
        data40_1.Interaction_Type[i] = 2
        
    elif(data40_1.FirstVID[i] in (g1_40_1)) and (data40_1.SecondVID[i] in (g1_40_1)):
        data40_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("40% done") 



for i in range (0, length50_1):
    if(data50_1.FirstVID[i] in (f1_50_1)) and (data50_1.SecondVID[i] in (f1_50_1)):
        data50_1.Interaction_Type[i] = 0
        
    elif(data50_1.FirstVID[i] in (f1_50_1)) and (data50_1.SecondVID[i] in (g1_50_1)):
        data50_1.Interaction_Type[i] = 1
        
    elif(data50_1.FirstVID[i] in (g1_50_1)) and (data50_1.SecondVID[i] in (f1_50_1)):
        data50_1.Interaction_Type[i] = 2
        
    elif(data50_1.FirstVID[i] in (g1_50_1)) and (data50_1.SecondVID[i] in (g1_50_1)):
        data50_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("50% done") 




for i in range (0, length60_1):
    if(data60_1.FirstVID[i] in (f1_60_1)) and (data60_1.SecondVID[i] in (f1_60_1)):
        data60_1.Interaction_Type[i] = 0
        
    elif(data60_1.FirstVID[i] in (f1_60_1)) and (data60_1.SecondVID[i] in (g1_60_1)):
        data60_1.Interaction_Type[i] = 1
        
    elif(data60_1.FirstVID[i] in (g1_60_1)) and (data60_1.SecondVID[i] in (f1_60_1)):
        data60_1.Interaction_Type[i] = 2
        
    elif(data60_1.FirstVID[i] in (g1_60_1)) and (data60_1.SecondVID[i] in (g1_60_1)):
        data60_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("60% done") 



for i in range (0, length70_1):
    if(data70_1.FirstVID[i] in (f1_70_1)) and (data70_1.SecondVID[i] in (f1_70_1)):
        data70_1.Interaction_Type[i] = 0
        
    elif(data70_1.FirstVID[i] in (f1_70_1)) and (data70_1.SecondVID[i] in (g1_70_1)):
        data70_1.Interaction_Type[i] = 1
        
    elif(data70_1.FirstVID[i] in (g1_70_1)) and (data70_1.SecondVID[i] in (f1_70_1)):
        data70_1.Interaction_Type[i] = 2
        
    elif(data70_1.FirstVID[i] in (g1_70_1)) and (data70_1.SecondVID[i] in (g1_70_1)):
        data70_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("70% done") 



for i in range (0, length80_1):
    if(data80_1.FirstVID[i] in (f1_80_1)) and (data80_1.SecondVID[i] in (f1_80_1)):
        data80_1.Interaction_Type[i] = 0
        
    elif(data80_1.FirstVID[i] in (f1_80_1)) and (data80_1.SecondVID[i] in (g1_80_1)):
        data80_1.Interaction_Type[i] = 1
        
    elif(data80_1.FirstVID[i] in (g1_80_1)) and (data80_1.SecondVID[i] in (f1_80_1)):
        data80_1.Interaction_Type[i] = 2
        
    elif(data80_1.FirstVID[i] in (g1_80_1)) and (data80_1.SecondVID[i] in (g1_80_1)):
        data80_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("80% done") 




for i in range (0, length90_1):
    if(data90_1.FirstVID[i] in (f1_90_1)) and (data90_1.SecondVID[i] in (f1_90_1)):
        data90_1.Interaction_Type[i] = 0
        
    elif(data90_1.FirstVID[i] in (f1_90_1)) and (data90_1.SecondVID[i] in (g1_90_1)):
        data90_1.Interaction_Type[i] = 1
        
    elif(data90_1.FirstVID[i] in (g1_90_1)) and (data90_1.SecondVID[i] in (f1_90_1)):
        data90_1.Interaction_Type[i] = 2
        
    elif(data90_1.FirstVID[i] in (g1_90_1)) and (data90_1.SecondVID[i] in (g1_90_1)):
        data90_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("90% done") 




for i in range (0, length100_1):
    if(data100_1.FirstVID[i] in (f1_100_1)) and (data100_1.SecondVID[i] in (f1_100_1)):
        data100_1.Interaction_Type[i] = 0
        
    elif(data100_1.FirstVID[i] in (f1_100_1)) and (data100_1.SecondVID[i] in (g1_100_1)):
        data100_1.Interaction_Type[i] = 1
        
    elif(data100_1.FirstVID[i] in (g1_100_1)) and (data100_1.SecondVID[i] in (f1_100_1)):
        data100_1.Interaction_Type[i] = 2
        
    elif(data100_1.FirstVID[i] in (g1_100_1)) and (data100_1.SecondVID[i] in (g1_100_1)):
        data100_1.Interaction_Type[i] = 3
        
    else:
        print("flag this")
                
print("100% done")
# Out:
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.
# 0% done
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# C:\Users\z5130037\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
#[FIFTH BLOCK]
datasave0_1 = data0_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final0_3.csv"))
datasave10_1 = data10_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final10_3.csv"))
datasave20_1 = data20_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final20_3.csv"))
datasave30_1 = data30_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final30_3.csv"))
datasave40_1 = data40_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final40_3.csv"))
datasave50_1 = data50_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final50_3.csv"))
datasave60_1 = data60_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final60_3.csv"))
datasave70_1 = data70_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final70_3.csv"))
datasave80_1 = data80_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final80_3.csv"))
datasave90_1 = data90_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final90_3.csv"))
datasave100_1 = data100_1.to_csv((r"D:\\PARETO_MODELS\\New\\ModelD0_H0.75N\\Results\\bugsbunny\\Final100_3.csv"))

# %%
#[SIXTH BLOCK]
print(" This is for 0% CAV Penetration")
p0MVMV = data0_1.loc[data0_1['Interaction_Type'] == 0]
p0MVAV = data0_1.loc[data0_1['Interaction_Type'] == 1]
p0AVMV = data0_1.loc[data0_1['Interaction_Type'] == 2]
p0AVAV = data0_1.loc[data0_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p0MVMV))
print("MV-AV")
print(len(p0MVAV))
print("AV-MV")
print(len(p0AVMV))
print("AV-AV")
print(len(p0AVAV))


print(" This is for 10% CAV Penetration")

p10MVMV = data10_1.loc[data10_1['Interaction_Type'] == 0]
p10MVAV = data10_1.loc[data10_1['Interaction_Type'] == 1]
p10AVMV = data10_1.loc[data10_1['Interaction_Type'] == 2]
p10AVAV = data10_1.loc[data10_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p10MVMV))
print("MV-AV")
print(len(p10MVAV))
print("AV-MV")
print(len(p10AVMV))
print("AV-AV")
print(len(p10AVAV))

print(" This is for 20% CAV Penetration")

p20MVMV = data20_1.loc[data20_1['Interaction_Type'] == 0]
p20MVAV = data20_1.loc[data20_1['Interaction_Type'] == 1]
p20AVMV = data20_1.loc[data20_1['Interaction_Type'] == 2]
p20AVAV = data20_1.loc[data20_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p20MVMV))
print("MV-AV")
print(len(p20MVAV))
print("AV-MV")
print(len(p20AVMV))
print("AV-AV")
print(len(p20AVAV))

print(" This is for 30% CAV Penetration")

p30MVMV = data30_1.loc[data30_1['Interaction_Type'] == 0]
p30MVAV = data30_1.loc[data30_1['Interaction_Type'] == 1]
p30AVMV = data30_1.loc[data30_1['Interaction_Type'] == 2]
p30AVAV = data30_1.loc[data30_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p30MVMV))
print("MV-AV")
print(len(p30MVAV))
print("AV-MV")
print(len(p30AVMV))
print("AV-AV")
print(len(p30AVAV))

print(" This is for 40% CAV Penetration")

p40MVMV = data40_1.loc[data40_1['Interaction_Type'] == 0]
p40MVAV = data40_1.loc[data40_1['Interaction_Type'] == 1]
p40AVMV = data40_1.loc[data40_1['Interaction_Type'] == 2]
p40AVAV = data40_1.loc[data40_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p40MVMV))
print("MV-AV")
print(len(p40MVAV))
print("AV-MV")
print(len(p40AVMV))
print("AV-AV")
print(len(p40AVAV))

print(" This is for 50% CAV Penetration")

p50MVMV = data50_1.loc[data50_1['Interaction_Type'] == 0]
p50MVAV = data50_1.loc[data50_1['Interaction_Type'] == 1]
p50AVMV = data50_1.loc[data50_1['Interaction_Type'] == 2]
p50AVAV = data50_1.loc[data50_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p50MVMV))
print("MV-AV")
print(len(p50MVAV))
print("AV-MV")
print(len(p50AVMV))
print("AV-AV")
print(len(p50AVAV))

print(" This is for 60% CAV Penetration")

p60MVMV = data60_1.loc[data60_1['Interaction_Type'] == 0]
p60MVAV = data60_1.loc[data60_1['Interaction_Type'] == 1]
p60AVMV = data60_1.loc[data60_1['Interaction_Type'] == 2]
p60AVAV = data60_1.loc[data60_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p60MVMV))
print("MV-AV")
print(len(p60MVAV))
print("AV-MV")
print(len(p60AVMV))
print("AV-AV")
print(len(p60AVAV))

print(" This is for 70% CAV Penetration")

p70MVMV = data70_1.loc[data70_1['Interaction_Type'] == 0]
p70MVAV = data70_1.loc[data70_1['Interaction_Type'] == 1]
p70AVMV = data70_1.loc[data70_1['Interaction_Type'] == 2]
p70AVAV = data70_1.loc[data70_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p70MVMV))
print("MV-AV")
print(len(p70MVAV))
print("AV-MV")
print(len(p70AVMV))
print("AV-AV")
print(len(p70AVAV))

print(" This is for 80% CAV Penetration")

p80MVMV = data80_1.loc[data80_1['Interaction_Type'] == 0]
p80MVAV = data80_1.loc[data80_1['Interaction_Type'] == 1]
p80AVMV = data80_1.loc[data80_1['Interaction_Type'] == 2]
p80AVAV = data80_1.loc[data80_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p80MVMV))
print("MV-AV")
print(len(p80MVAV))
print("AV-MV")
print(len(p80AVMV))
print("AV-AV")
print(len(p80AVAV))

print(" This is for 90% CAV Penetration")

p90MVMV = data90_1.loc[data90_1['Interaction_Type'] == 0]
p90MVAV = data90_1.loc[data90_1['Interaction_Type'] == 1]
p90AVMV = data90_1.loc[data90_1['Interaction_Type'] == 2]
p90AVAV = data90_1.loc[data90_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p90MVMV))
print("MV-AV")
print(len(p90MVAV))
print("AV-MV")
print(len(p90AVMV))
print("AV-AV")
print(len(p90AVAV))

print(" This is for 100% CAV Penetration")

p100MVMV = data100_1.loc[data0_1['Interaction_Type'] == 0]
p100MVAV = data100_1.loc[data0_1['Interaction_Type'] == 1]
p100AVMV = data100_1.loc[data0_1['Interaction_Type'] == 2]
p100AVAV = data100_1.loc[data0_1['Interaction_Type'] == 3]
print("MV-MV")
print(len(p100MVMV))
print("MV-AV")
print(len(p100MVAV))
print("AV-MV")
print(len(p100AVMV))
print("AV-AV")
print(len(p100AVAV))
# Out:
#  This is for 0% CAV Penetration
# MV-MV
# 7563
# MV-AV
# 0
# AV-MV
# 0
# AV-AV
# 0
#  This is for 10% CAV Penetration
# MV-MV
# 2999
# MV-AV
# 335
# AV-MV
# 340
# AV-AV
# 34
#  This is for 20% CAV Penetration
# MV-MV
# 1792
# MV-AV
# 459
# AV-MV
# 442
# AV-AV
# 111
#  This is for 30% CAV Penetration
# MV-MV
# 1270
# MV-AV
# 542
# AV-MV
# 508
# AV-AV
# 240
#  This is for 40% CAV Penetration
# MV-MV
# 946
# MV-AV
# 612
# AV-MV
# 644
# AV-AV
# 390
#  This is for 50% CAV Penetration
# MV-MV
# 661
# MV-AV
# 648
# AV-MV
# 642
# AV-AV
# 713
#  This is for 60% CAV Penetration
# MV-MV
# 477
# MV-AV
# 698
# AV-MV
# 696
# AV-AV
# 914
#  This is for 70% CAV Penetration
# MV-MV
# 259
# MV-AV
# 623
# AV-MV
# 631
# AV-AV
# 1482
#  This is for 80% CAV Penetration
# MV-MV
# 147
# MV-AV
# 523
# AV-MV
# 545
# AV-AV
# 2096
#  This is for 90% CAV Penetration
# MV-MV
# 33
# MV-AV
# 342
# AV-MV
# 328
# AV-AV
# 2867
#  This is for 100% CAV Penetration
# MV-MV
# 3809
# MV-AV
# 0
# AV-MV
# 0
# AV-AV
# 0
